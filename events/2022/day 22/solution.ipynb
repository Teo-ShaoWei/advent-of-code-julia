# %% [markdown]
# # Advent of Code 2022 Day 22
# [link](https://adventofcode.com/2022/day/22)

# %% [markdown]
# ## include code file using Revise

# %%
using Revise

# %%
includet("functions.jl")

# %% [markdown]
# ## set logger

# %%
import Logging
import TerminalLoggers

Logging.global_logger(TerminalLoggers.TerminalLogger())
# Out:
# Base.CoreLogging.SimpleLogger(IJulia.IJuliaStdio{Base.PipeEndpoint}(IOContext(Base.PipeEndpoint(RawFD(45) open, 0 bytes waiting))), Info, Dict{Any, Int64}())

# %% [markdown]
# ## read input

# %%
PDS1 = parse_puzzle_file("sample1.txt", PuzzleSample1)

PDS1.rules |> println
PDS1 |> print_whole_area
nothing
# Out:
# Rule[10, R, 5, L, 5, R, 10, L, 4, R, 5, L, 5]
# size: 12 × 16
# axes: (1:12, 1:16)
#         ···#
#         ·#··
#         #···
#         ····
# ···#·······#
# ········#···
# ··#····#····
# ··········#·
#         ···#····
#         ·····#··
#         ·#······
#         ······#·

# %%
PDI = parse_puzzle_file("input.txt", PuzzleInput)

PDI.rules |> println
PDI |> print_whole_area
nothing
# Out:
# Rule[24, R, 38, L, 36, R, 1, R, 28, L, 11, R, 39, L, 5, R, 36, R, 41, L, 31, R, 9, L, 16, R, 4, R, 36, L, 38, R, 31, L, 38, R, 17, L, 18, R, 31, R, 6, L, 40, L, 2, L, 19, R, 41, R, 27, R, 24, L, 33, R, 21, L, 27, R, 7, R, 11, R, 27, R, 11, R, 2, L, 46, L, 34, R, 3, L, 23, R, 29, L, 45, L, 13, L, 25, L, 37, R, 46, L, 21, L, 20, L, 22, L, 4, R, 31, R, 36, R, 10, R, 13, R, 39, R, 27, L, 27, R, 20, L, 12, R, 49, R, 21, R, 44, R, 50, L, 5, L, 9, R, 13, L, 11, R, 26, R, 44, L, 48, R, 44, L, 24, R, 44, R, 46, L, 49, R, 20, R, 13, R, 27, R, 4, L, 25, L, 5, L, 39, R, 10, L, 29, L, 12, R, 3, R, 39, L, 11, R, 49, L, 13, R, 45, L, 2, R, 3, L, 50, L, 12, L, 33, R, 22, L, 20, L, 2, R, 37, L, 32, R, 32, L, 1, L, 41, L, 26, R, 1, R, 10, R, 25, R, 49, L, 48, L, 24, R, 48, L, 27, R, 43, L, 28, R, 7, L, 30, L, 15, R, 46, R, 32, L, 11, R, 7, L, 2, R, 24, R, 32, R, 16, R, 16, R, 10, R, 28, R, 11, R, 19, R, 5, L, 45, R, 4, L, 20, R, 49, R, 24, R, 44, L, 31, L, 46, L, 29, L, 32, R, 2, L, 48, L, 33, R, 36, R, 44, L, 41, R, 37, L, 17, L, 35, R, 40, R, 14, R, 48, L, 45, L, 16, R, 42, R, 30, L, 22, R, 28, L, 17, L, 2, R, 24, R, 22, L, 37, R, 3, R, 6, R, 32, L, 4, R, 1, R, 42, L, 33, R, 44, L, 9, R, 22, R, 19, L, 16, L, 17, R, 17, R, 37, L, 45, R, 46, R, 1, R, 34, R, 45, L, 10, R, 22, R, 12, R, 28, L, 42, R, 31, L, 27, L, 33, R, 24, R, 29, R, 24, L, 40, L, 41, L, 26, R, 9, R, 23, R, 11, R, 20, R, 13, R, 28, R, 20, R, 16, L, 17, L, 14, R, 48, L, 34, L, 12, R, 16, L, 12, L, 30, R, 42, R, 15, R, 19, R, 20, R, 15, L, 39, L, 8, R, 33, L, 31, R, 35, L, 12, R, 29, L, 37, R, 42, R, 4, L, 41, L, 30, R, 15, L, 12, L, 6, R, 27, L, 10, R, 23, R, 17, L, 10, L, 23, R, 35, L, 48, R, 47, L, 46, L, 12, L, 27, L, 22, L, 46, R, 50, L, 37, R, 45, L, 37, R, 21, L, 8, L, 2, L, 18, R, 46, L, 3, R, 23, R, 18, R, 32, R, 37, L, 27, R, 43, L, 39, L, 23, L, 40, L, 27, L, 22, L, 22, R, 30, L, 30, R, 35, R, 38, L, 40, L, 50, R, 8, R, 9, L, 20, R, 29, L, 27, R, 9, R, 2, R, 16, R, 32, L, 4, R, 49, L, 44, L, 13, R, 17, L, 47, L, 29, R, 46, R, 22, L, 27, L, 7, L, 37, L, 17, L, 7, R, 2, R, 3, R, 24, L, 47, R, 50, L, 17, L, 17, R, 31, L, 23, R, 19, L, 6, L, 42, L, 42, L, 43, L, 5, R, 42, R, 36, R, 47, R, 13, L, 7, L, 42, R, 22, L, 2, L, 5, R, 31, R, 49, R, 43, R, 35, L, 19, L, 29, R, 11, R, 3, R, 29, R, 34, L, 41, R, 45, L, 28, L, 39, L, 14, R, 31, L, 4, R, 23, L, 35, R, 40, R, 32, R, 39, L, 36, L, 6, R, 13, R, 37, R, 23, R, 21, L, 14, R, 37, L, 35, R, 12, R, 50, L, 35, L, 5, R, 25, L, 45, L, 8, L, 8, R, 14, L, 24, R, 25, L, 29, L, 20, R, 3, L, 36, L, 16, R, 22, R, 2, R, 19, L, 23, L, 8, L, 3, R, 43, L, 22, R, 27, L, 31, L, 48, R, 21, R, 2, R, 7, L, 27, R, 36, L, 5, L, 15, L, 5, R, 8, R, 41, L, 46, R, 28, L, 26, R, 45, R, 42, R, 9, L, 38, R, 35, R, 38, R, 22, R, 18, R, 13, L, 40, L, 11, L, 5, L, 44, L, 27, L, 28, L, 23, L, 37, R, 8, L, 40, L, 13, R, 35, R, 48, R, 18, R, 29, R, 7, L, 9, L, 10, L, 45, L, 12, L, 45, R, 21, L, 28, L, 36, R, 49, R, 18, R, 40, L, 41, L, 8, R, 2, L, 40, R, 9, R, 10, R, 42, L, 23, R, 19, R, 12, L, 27, L, 33, R, 42, L, 30, L, 25, R, 12, R, 5, R, 36, L, 14, L, 14, L, 4, L, 24, L, 39, R, 14, R, 37, L, 1, R, 16, L, 28, L, 44, L, 12, L, 45, R, 21, R, 7, R, 5, R, 1, L, 7, R, 48, L, 38, R, 1, L, 49, R, 15, L, 26, L, 12, R, 36, L, 7, R, 46, L, 24, L, 28, R, 39, R, 7, R, 33, L, 49, R, 34, R, 37, L, 34, R, 40, R, 18, R, 44, R, 26, R, 48, L, 31, L, 50, R, 48, R, 33, R, 15, L, 48, L, 2, R, 36, L, 46, L, 12, R, 38, R, 10, R, 20, R, 48, R, 38, R, 25, L, 9, L, 23, R, 39, R, 28, R, 50, L, 47, L, 47, L, 49, L, 39, L, 46, L, 8, R, 15, L, 19, R, 27, L, 48, R, 48, L, 25, R, 46, R, 27, R, 1, R, 15, R, 15, R, 46, R, 41, L, 50, R, 25, R, 38, R, 33, L, 41, L, 18, L, 43, L, 35, L, 43, R, 18, L, 29, R, 8, R, 7, R, 35, L, 43, L, 46, R, 32, L, 17, R, 31, R, 39, R, 30, L, 32, L, 20, L, 10, L, 34, R, 25, R, 11, R, 10, L, 49, R, 31, R, 45, R, 1, L, 18, R, 30, L, 15, L, 48, L, 21, R, 8, R, 22, L, 35, L, 49, L, 7, L, 6, R, 23, L, 4, R, 31, R, 42, L, 7, L, 20, R, 41, L, 24, L, 40, L, 46, R, 2, L,  ...
# size: 200 × 150
# axes: (1:200, 1:150)
#                                                   ·············#·································#···#·······················##··············#·····#··
#                                                   ·#··#······#··············#···············#··#····#··#·············#································
#                                                   ··········#···#······#···········································#·······#·#············#···········
#                                                   ·············#············#···#·#··········#··#···#··········#·········#······#············#······#·
#                                                   ····················#················#·············································#················
#                                                   ····#·##··#····················#···············#··········#···············#········#·············##·
#                                                   ···#··#·························································#···············#···················
#                                                   ········································#···························#·············#·················
#                                                   ···#·············##··················#······#·····##··#·#················#············#·············
#                                                   #··············#·········································###··············#······#·········#····#···
#                                                   ·····##···#··#··#····#·····#················#·#······#······##········#······#··#·······#···········
#                                                   ·······#········#·············#············#····#····#····························##················
#                                                   ··········#···········#························#·················#··#·#··#·····#·······##··········#
#                                                   ·#···#·····················#···························##····#·················#····················
#                                                   ·#·····#·#··##····························#··············#·············#············#···············
#                                                   ·········#·#·················#··················#·······#······#·····················#··············
#                                                   ····#·##·····················#·······················#·················#·············#···#·········#
#                                                   ········#···········#······#··············#········#·#··#·····································#····#
#                                                   ··#················#····#·····#······#···········#···················##··#·················#········
#                                                   ··········#·····#················#·#·#···················#···#·························#·······#·#··
#                                                   ·····#··················#········#··#················#······················#·····#·#···············
#                                                   ··························#······························#··········································
#                                                   ········#··············#··#····#·##········##··#·····#························#·······#·············
#                                                   ·················#····#·········#··········#·##·#···············#··············#·#·······#···#······
#                                                   ·····#··············#····························#······#··················#··············#·········
#                                                   ··············#···#·#···#········#····················#·····##··#······#························#···
#                                                   ··················#···········#·············#········#·#·····················#·····#····##··········
#                                                   ···········##··········#··································#·············##·#·················#······
#                                                   ···#······················#·····#·············#········###··#··················#········#···········
#                                                   ·#···········#············#········#································#···········#·········#······#·#
#                                                   ··#····················#·##·##·#···#··········#··#······#············#················#·········##··
#                                                   ···##·#·····#······##·······#·#····#······················#······#···#··#············#···········#··
#                                                   ···············#···#·············##········#·········#··········#···································
#                                                   #················###·····#······#·············#···#···········#·#···································
#                                                   ··········#··········#····#·#·············#····#··········#······················#······#·····#·····
#                                                   ···#··#··························#·#···#··············································##············
#                                                   ··#··················#············##············#·····#···#·····#··········#····#········#·········#
#                                                   ······#···············#·····#····························#·····#························#·········#·
#                                                   #··#········#·················#······················#··#·················#·#····#·····#·#··#····##·
#                                                   ·#··#···············#·················#·#···#········#·········#································#···
#                                                   #······#·#··························································································
#                                                   ··········#·····#·····#···························#··#·······#···##······#······#·#·······##········
#                                                   ····················##·······###·········#···#···········#·················#······#···#·····#·······
#                                                   ··············#········#·······#···················#··························#··········#····#··#··
#                                                   ·········##···#········#·###···#···········#···············#··················#······#·#·#·#·#······
#                                                   ····#·····································································#·························
#                                                   ····················#··········#··#···#··#············#··········#····##····#···#···················
#                                                   ·········#·········#······················#····##···········#·······#················#····#··#······
#                                                   ··········#···················#·······#·##··········#··········#····································
#                                                   #···········#····#·······#············#·······#···#··#·····#··········#·#··················#········
#                                                   ·#··············#··#···#····#·······##····#·······
#                                                   ·#··#······················#··················#·##
#                                                   ··#·······································#·#·····
#                                                   ·#··········#························#············
#                                                   ·#········#·································#·····
#                                                   #······#··#········#··#···························
#                                                   ·······#·····#······#··········#··#··············#
#                                                   ········#····#················#········##····#····
#                                                   ·············#······#·············#·········#·····
#                                                   ·································#······#·········
#                                                   ····#·········#·····#·········#·#·················
#                                                   ·······#·###·····##·#·#··························#
#                                                   ············#··········#·········#······##··#··#··
#                                                   ·······························#······#·#·········
#                                                   ····#········#··#···#·················#···········
#                                                   #···##···#·········#··············##···#··········
#                                                   ·······#··#·············#····#··#··#·····#·····#··
#                                                   #····························#····#··#·····#······
#                                                   ············##···········#······#·················
#                                                   ········#··············#········#·················
#                                                   ···········#··········#············#·#··#········#
#                                                   ·················#··#·····························
#                                                   ··········#·························#····#········
#                                                   ······#························#············#·····
#                                                   ·······#···#·············#·#········###···········
#                                                   ················#·#·····#·#······#·····#··#·#·····
#                                                   ········#·············#······#·············#···#··
#                                                   ···#·#····#·············##·#···········#·······#··
#                                                   ·##··········#·······#···#···#···###··········#···
#                                                   ···#······#·········#····#·····##·················
#                                                   ··········#······#········#··#·#·······#··········
#                                                   ·················#········#·····#·················
#                                                   ···#··········##······#··········#··#···#······#··
#                                                   ·············#····#··#·#······#···············##··
#                                                   ····#···#······#····#····#·#··#···················
#                                                   ···#·············#···················#············
#                                                   ·····#················##··#····#·······#·······#·#
#                                                   ········#·········#····#········#·················
#                                                   ··················#··························#····
#                                                   ·····································#············
#                                                   ··········#·····#··························#·····#
#                                                   ··#·········##···#···#··#·························
#                                                   ·············#·······#················#···········
#                                                   ··········#··································#·#··
#                                                   ···#········#····················#·#·····#········
#                                                   ··················#···········#··············#····
#                                                   ····#······#······#···#···#···#···················
#                                                   ······································#···#·······
#                                                   ·····#·····#···········#······#···················
#                                                   ··········#···················#··············#··##
# ·····#··#············##·······##···#················#························#·········#···#········
# ········································#······························##···············#···········
# ·····##·#··········#·#··········#···#········#··················##···#················#·············
# ·······································##······#······#······#····················#············#····
# ················#·······#········##·······#············#··························#·············#···
# ·································#·#·····#············#····················#·#····#··#····##·##··#··
# ·················#··#·······#·····#················#······················#·············#·······##··
# ········#·········#··························#····#·#··#·······#···#················#······#··#·····
# ············#·#·····#············##·#···············#···························#········#··········
# ·····························#··##··············#································##··#··············
# ·················#·#···#··········#·····#···························································
# ··············#·····#·················#··#····#·············##·········#···················#······#·
# ·#·#···········#······················#··················#···········#····#··#····#···#······#······
# ·#·#························#······#····#······#···························#··#·#··#·········#······
# ·····#············#···#···········#······························#··········#·····················#·
# ····#·##·····#·····················#········#·················#········#·····##··#·········#··#···##
# ··················#···##··········································#·#·······························
# ·····#····#·······················#·#·························#··###··········#·······#·······##····
# ##·········#················###···#··#······#·····#·················································
# ·········#··········###····#·····#··#···#·#··················#·············#··#······##··#·······#··
# ·#·······#············#·········#·············#···#··········#·······#··#···············#···········
# ···#····#······#····#··········#·#··#·#·#············#··········#··············#······#·············
# ···········#····#·····#·#······················#··#·········#·········#····#························
# ···············##····#···············#··········#··#··#····················#·##··················#·#
# ········##··#··················#··········#·············#·················#··#·················#····
# ·#····················#···································#··#····##··#·#··············#············
# ···#··#·····#···#····#·························#·····················#·#··#········#··········#·····
# ········##····#····#······························#······#···········#················#·············
# ················#····················#················#·#···········#···········#··#·····#··#·····#·
# ···#··#·#·········#·#···#············#··#···············#······························#········#···
# ·##·······##···············#·······#·······#···#·······#·#····#·····················#·#······#·##···
# ·····#········#·#·············##······#·························································#···
# ##···········································#·······#··#········##··················#··············
# ··#·#···············#··················#··········#········#···························#············
# ··············#····#·#···········#···········#·······#·············#········#··#·#·················#
# ·······················#··········#·······#····························#············#·······#·#····#
# #························#···##··#·················#·#······················#······#·#·········#····
# ············#······#·##········#·····#········#·············#···········#···#······#··········#·····
# ·······#··#····#········#··············#·······#·#·····#··#················#··#·····#···············
# ····#·················#·····················#······#········##······#·······························
# ·············#·······#·#·········##·#··············##················#······#················#··#·#·
# ·····#·······················#···················································#···············#··
# #·······#···············#·······#·························#···········#·#···#·······##··············
# #·······················#··#········#············##············#··#··##··········#······#·#·····#···
# ·#····#····#·##·#······##·#··#·#·##··#·#··············#························#···#················
# ····#···#······#·#·····························##··········#······#···#··#············#·············
# ·····················#··#·#·······#····························#·#·············#···#···#···#·····#··
# ·······························###··························#·······#··#···············##···········
# ··············#··#······#····················#················#···#···········##·············#······
# ······#·······#···#·····#··#··················#···#···#·········#·····#·············#·········#··#··
# ···#·······················#··#·····##············
# ······················#··#····#··#················
# ····#············#····#····#·#····················
# ··············#············#··················#···
# ····#·#·······#··································#
# ··#·····#··········#·········#··················#·
# ············#···············#···········#·········
# ···#······#··········#··#··##·············#·······
# ····#·····#················#······#····##·········
# ····#·#·········#·······························#·
# ···························#········#·············
# ···#·································#············
# ···························##··#··················
# ·····#···#······#·········#············#········#·
# ············#·······················#··········#··
# #·#·········#·················#·····##·#·······#··
# #···········#····#·····#·······#···#··············
# ·······#···#····#························#·#······
# ·#······················#····#···#···#············
# ··········#··········#··#··········#··········#·#·
# ····························#··············#··#···
# ·······#·······#··································
# ···#·························#·········#········##
# ·#···#······#····#··#·····#····##············#····
# ··#····#·····#············##········#·········#···
# ············#············#····················##··
# ················#·········#·················#·····
# ······················#··#··#·······#·············
# ····##··#···················#··················#··
# ·············#·······#··········#·········#······#
# ····#···#······#····#··#······#···················
# ············#··············#···········#··········
# ·#············#··············#····················
# ·····###························#·················
# ···············#··································
# ····#·······#·····································
# ·················#··············#······#··········
# ·········#···········#·····#·····#·······#·#··##··
# ····#·#············#····#··#·······#········#··#··
# ··#···#·················#········#·##·······#·····
# ··············#··················##···#···········
# ·······#··················#·#··········#··········
# ···························#·····················#
# ······#·················#·························
# ····#·····················#·····#······#······#···
# ··················#·#·····#····#·············#····
# ··········#··················#·#··················
# ······#····#····················#················#
# #·#··················#····························
# ·············································#····

# %% [markdown]
# ## part 1

# %%
FACE_MAP_PDS1 = identify_faces(typeof(PDS1))
# Out:
# 6-element Vector{CartesianIndex{2}}:
#  CI(1, 3)
#  CI(2, 1)
#  CI(2, 2)
#  CI(2, 3)
#  CI(3, 3)
#  CI(3, 4)

# %%
PDS1.faces[1][0] |> rotl90
# Out:
# 4×4 Matrix{Char}:
#  #  .  .  .
#  .  .  .  .
#  .  #  .  .
#  .  .  #  .

# %%
PDS1.faces[1][1]
# Out:
# 4×4 Matrix{Char}:
#  #  .  .  .
#  .  .  .  .
#  .  #  .  .
#  .  .  #  .

# %%
[x[0] for x in PDS1.faces] .|> display;
# Out:
# 4×4 Matrix{Char}:
#  .  .  .  #
#  .  #  .  .
#  #  .  .  .
#  .  .  .  .
# 4×4 Matrix{Char}:
#  .  .  .  #
#  .  .  .  .
#  .  .  #  .
#  .  .  .  .
# 4×4 Matrix{Char}:
#  .  .  .  .
#  .  .  .  .
#  .  .  .  #
#  .  .  .  .
# 4×4 Matrix{Char}:
#  .  .  .  #
#  #  .  .  .
#  .  .  .  .
#  .  .  #  .
# 4×4 Matrix{Char}:
#  .  .  .  #
#  .  .  .  .
#  .  #  .  .
#  .  .  .  .
# 4×4 Matrix{Char}:
#  .  .  .  .
#  .  #  .  .
#  .  .  .  .
#  .  .  #  .

# %%
WARP_MAP_PDS1_P1 = make_warp_map(PDS1, Part1())
# Out:
# Dict{NamedTuple{(:face, :dir), Tuple{Int64, Int64}}, NamedTuple{(:face, :dir), Tuple{Int64, Int64}}} with 24 entries:
#   (face = 5, dir = 3) => (face = 4, dir = 3)
#   (face = 6, dir = 1) => (face = 6, dir = 1)
#   (face = 3, dir = 0) => (face = 4, dir = 0)
#   (face = 6, dir = 0) => (face = 5, dir = 0)
#   (face = 1, dir = 1) => (face = 4, dir = 1)
#   (face = 5, dir = 2) => (face = 6, dir = 2)
#   (face = 4, dir = 3) => (face = 1, dir = 3)
#   (face = 2, dir = 2) => (face = 4, dir = 2)
#   (face = 1, dir = 0) => (face = 1, dir = 0)
#   (face = 2, dir = 3) => (face = 2, dir = 3)
#   (face = 5, dir = 0) => (face = 6, dir = 0)
#   (face = 5, dir = 1) => (face = 1, dir = 1)
#   (face = 4, dir = 2) => (face = 3, dir = 2)
#   (face = 2, dir = 1) => (face = 2, dir = 1)
#   (face = 3, dir = 2) => (face = 2, dir = 2)
#   (face = 4, dir = 0) => (face = 2, dir = 0)
#   (face = 4, dir = 1) => (face = 5, dir = 1)
#   (face = 3, dir = 3) => (face = 3, dir = 3)
#   (face = 2, dir = 0) => (face = 3, dir = 0)
#   (face = 6, dir = 3) => (face = 6, dir = 3)
#   (face = 3, dir = 1) => (face = 3, dir = 1)
#   (face = 1, dir = 2) => (face = 1, dir = 2)
#   (face = 1, dir = 3) => (face = 5, dir = 3)
#   (face = 6, dir = 2) => (face = 5, dir = 2)

# %%
get_starting_pos(PDS1)
# Out:
# (ci = CI(1, 1), face = 1, dir = 0)

# %%
move(get_starting_pos(PDS1), PDS1.faces, 4, WARP_MAP_PDS1_P1)
# Out:
# (ci = CI(1, 2), face = 1, dir = 0)

# %%
follow_rule(
    PDS1.rules[1],
    get_starting_pos(PDS1),
    PDS1.faces,
    4,
    WARP_MAP_PDS1_P1,
)
# Out:
# (ci = CI(1, 3), face = 1, dir = 0)

# %%
follow_rule(
    PDS1.rules[2],
    get_starting_pos(PDS1),
    PDS1.faces,
    4,
    WARP_MAP_PDS1_P1,
)
# Out:
# (ci = CI(4, 1), face = 1, dir = 1)

# %%
follow_rules(
    PDS1;
    puzzle_part = Part1(),
)
# Out:
# (ci = CI(6, 8), dir = 0)

# %% [markdown]
# ### answer

# %%
@time @info(
    "part 1 answer",
    result1(PDS1),
    result1(PDI),
)
# Out:
#   0.588721 seconds (2.47 M allocations: 121.431 MiB, 2.66% gc time, 51.79% compilation time)
# ┌ Info: part 1 answer
# │   result1(PDS1) = 6032
# └   result1(PDI) = 196134

# %% [markdown]
# ## part 2

# %% [markdown]
# ### answer

# %%
@time @info(
    "part 2 answer",
    result2(PDS1),
    result2(PDI),
)
# Out:
#   0.417562 seconds (918.40 k allocations: 43.129 MiB, 1.69% gc time, 30.13% compilation time)
# ┌ Info: part 2 answer
# │   result2(PDS1) = 5031
# └   result2(PDI) = 146011
